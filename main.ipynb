# %%
import pandas as pd
import requests
import os
import re
from bs4 import BeautifulSoup
from textblob import TextBlob
import nltk
from nltk.corpus import cmudict

# %%
excel_file_path = "C:/Users/Harry/OneDrive/Desktop/interntask/Input.xlsx"
df = pd.read_excel(excel_file_path)

# %%
url_column = 'URL'
id_column = 'URL_ID'

# %%
output_dir = "C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles"
os.makedirs(output_dir, exist_ok=True)

# %%
# Function to fetch and extract article content
def fetch_and_extract_article(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.content, 'html.parser')
        title_tag = soup.find('h1', class_='entry-title')
        title = title_tag.get_text(strip=True) if title_tag else 'No Title'
        content_div = soup.find('div', class_='td-post-content')
        
        if content_div:
            paragraphs = content_div.find_all('p')
            article_text = '\n'.join(paragraph.get_text(strip=True) for paragraph in paragraphs)
        else:
            article_text = ''

        full_text = f"{title}\n\n{article_text}"
        return full_text
    except Exception as e:
        print(f"Error fetching or extracting content from {url}: {e}")
        return ''

# %%
nltk.download('cmudict')
d = cmudict.dict()
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\Harry\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!

# %%
def syllable_count(word):
    word = word.lower()
    
    if word in d:
        return max(
            len([syllable for syllable in pronunciation if syllable[-1].isdigit()])
            for pronunciation in d[word]
        )
    return 0

# %%
#function to handle encoding error
def load_file_with_encoding(file_path, encodings=['utf-8', 'latin-1']):
    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as f:
                return f.read()
        except (UnicodeDecodeError, IOError):
            continue
    raise UnicodeDecodeError(f"Failed to read the file with any of the given encodings: {encodings}")

# %%
#function to load stopwords directory
def StopWords(dir_path):
    stopwords = set()
    for file in os.listdir(dir_path):
        if file.endswith(".txt"):
            file_path = os.path.join(dir_path, file)
            try:
                content = load_file_with_encoding(file_path)
                stopwords.update(line.strip().lower() for line in content.splitlines() if line.strip())
            except UnicodeDecodeError:
                print(f"Encoding error for file {file_path}. Skipping.")
    return stopwords

# %%
#function to load MasterDictonary directory
def MasterDict(dir_path):
    pos_words = set()
    neg_words = set()
    for file in os.listdir(dir_path):
        if file == 'positive-words.txt':
            file_path = os.path.join(dir_path, file)
            try:
                content = load_file_with_encoding(file_path)
                pos_words.update(line.strip().lower() for line in content.splitlines() if line.strip())
            except UnicodeDecodeError:
                print(f"Encoding error for file {file_path}. Skipping.")
        elif file == 'negative-words.txt':
            file_path = os.path.join(dir_path, file)
            try:
                content = load_file_with_encoding(file_path)
                neg_words.update(line.strip().lower() for line in content.splitlines() if line.strip())
            except UnicodeDecodeError:
                print(f"Encoding error for file {file_path}. Skipping.")
    return pos_words, neg_words

# %%
#function to load TextFiles directory
def TextFiles(dir_path):
    texts = {}
    for file in os.listdir(dir_path):
        if file.endswith(".txt"):
            file_path = os.path.join(dir_path, file)
            try:
                content = load_file_with_encoding(file_path)
                texts[file.replace('.txt', '')] = content
            except UnicodeDecodeError:
                print(f"Encoding error for file {file_path}. Skipping.")
    return texts

# %%
#function to save the variable answers
def OutputFile(file_path, results):
    df_existing = pd.read_excel(file_path)
    if 'URL_ID' not in df_existing.columns:
        raise KeyError("Missing 'URL_ID' column in the Excel file.")
    
    df_results = pd.DataFrame(results).T
    df_results.index.name = 'URL_ID'
    df_updated = df_existing.set_index('URL_ID').join(df_results)
    df_updated.to_excel(file_path)

# %%
#For web scrapping of articles
for _, row in df.iterrows():
    url_id = row[id_column]
    url = row[url_column]
    try:
        article_content = fetch_and_extract_article(url)
        if article_content:  # Check if content is not empty
            file_name = f"{url_id}.txt"
            file_path = os.path.join(output_dir, file_name)
            with open(file_path, 'w', encoding='utf-8') as file:
                file.write(article_content)
            print(f"Article saved to {file_path}")
        else:
            print(f"No content extracted for URL_ID {url_id} at {url}")
    except Exception as e:
        print(f"Failed to process URL_ID {url_id} at {url}: {e}")

print("Article extraction completed.")
# Out:
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2011.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2012.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2013.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2014.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2015.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2016.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2017.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2018.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2019.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2020.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2021.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2022.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2023.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2024.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2025.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2026.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2027.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2028.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2029.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2030.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2031.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2032.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2033.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2034.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2035.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2036.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2037.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2038.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2039.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2040.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2041.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2042.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2043.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2044.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2045.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2046.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2047.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2048.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2049.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2050.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2051.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2052.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2053.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2054.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2055.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2056.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2057.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2058.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2059.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2060.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2061.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2062.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2063.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2064.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2065.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2066.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2067.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2068.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2069.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2070.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2071.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2072.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2073.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2074.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2075.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2076.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2077.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2078.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2079.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2080.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2081.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2082.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2083.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2084.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2085.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2086.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2087.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2088.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2089.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2090.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2091.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2092.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2093.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2094.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2095.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2096.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2097.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2098.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2099.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2100.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2101.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2102.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2103.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2104.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2105.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2106.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2107.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2108.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2109.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2110.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2111.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2112.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2113.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2114.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2115.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2116.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2117.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2118.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2119.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2120.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2121.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2122.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2123.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2124.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2125.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2126.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2127.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2128.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2129.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2130.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2131.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2132.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2133.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2134.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2135.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2136.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2137.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2138.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2139.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2140.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2141.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2142.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2143.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2144.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2145.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2146.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2147.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2148.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2149.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2150.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2151.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2152.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2153.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2154.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2155.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2156.txt
# Article saved to C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles\bctech2157.txt
# Article extraction completed.

# %%
#function for text analysis
def TextAnalysis(text, stopwords, pos_words, neg_words):
    blob = TextBlob(text)
    sentences = blob.sentences
    words = [w for w in blob.words if w.lower() not in stopwords]
    
    word_count = len(words)
    complex_word_count = sum(1 for w in words if syllable_count(w) >= 3)
    avg_sentence_len = sum(len(s.words) for s in sentences) / len(sentences) if sentences else 0
    avg_word_len = sum(len(w) for w in words) / len(words) if words else 0
    
    pos_score = sum(1 for w in words if w.lower() in pos_words)
    neg_score = sum(1 for w in words if w.lower() in neg_words)
    
    polarity = blob.sentiment.polarity
    subjectivity = blob.sentiment.subjectivity
    
    perc_complex_words = (complex_word_count / word_count) * 100 if word_count else 0
    fog_index = 0.4 * (avg_sentence_len + perc_complex_words) if avg_sentence_len else 0
    personal_pronouns = sum(1 for w in words if w.lower() in ['i', 'me', 'my', 'mine', 'we', 'us', 'our', 'ours'])
    
    return {
        'POSITIVE SCORE': pos_score,
        'NEGATIVE SCORE': neg_score,
        'POLARITY SCORE': polarity,
        'SUBJECTIVITY SCORE': subjectivity,
        'AVG SENTENCE LENGTH': avg_sentence_len,
        'PERCENTAGE OF COMPLEX WORDS': perc_complex_words,
        'FOG INDEX': fog_index,
        'AVG NUMBER OF WORDS PER SENTENCE': avg_sentence_len,
        'COMPLEX WORD COUNT': complex_word_count,
        'WORD COUNT': word_count,
        'SYLLABLE PER WORD': sum(syllable_count(w) for w in words) / word_count if word_count else 0,
        'PERSONAL PRONOUNS': personal_pronouns,
        'AVG WORD LENGTH': avg_word_len
    }

# %%
text_files_dir = "C:/Users/Harry/OneDrive/Desktop/interntask/TextFiles"
stopwords_dir = "C:/Users/Harry/OneDrive/Desktop/interntask/StopWords"
master_dict_dir = "C:/Users/Harry/OneDrive/Desktop/interntask/MasterDictionary"
input_excel = "C:/Users/Harry/OneDrive/Desktop/interntask/Input.xlsx"

# %%
stopwords = StopWords(stopwords_dir)
pos_words, neg_words = MasterDict(master_dict_dir)

texts = TextFiles(text_files_dir)
results = {}
for url_id, text in texts.items():
    print(f"Processing {url_id}")
    results[url_id] = TextAnalysis(text, stopwords, pos_words, neg_words)

OutputFile(input_excel, results)
print("Analysis complete")
# Out:
# Processing bctech2011
# Processing bctech2012
# Processing bctech2013
# Processing bctech2014
# Processing bctech2015
# Processing bctech2016
# Processing bctech2017
# Processing bctech2018
# Processing bctech2019
# Processing bctech2020
# Processing bctech2021
# Processing bctech2022
# Processing bctech2023
# Processing bctech2024
# Processing bctech2025
# Processing bctech2026
# Processing bctech2027
# Processing bctech2028
# Processing bctech2029
# Processing bctech2030
# Processing bctech2031
# Processing bctech2032
# Processing bctech2033
# Processing bctech2034
# Processing bctech2035
# Processing bctech2036
# Processing bctech2037
# Processing bctech2038
# Processing bctech2039
# Processing bctech2040
# Processing bctech2041
# Processing bctech2042
# Processing bctech2043
# Processing bctech2044
# Processing bctech2045
# Processing bctech2046
# Processing bctech2047
# Processing bctech2048
# Processing bctech2049
# Processing bctech2050
# Processing bctech2051
# Processing bctech2052
# Processing bctech2053
# Processing bctech2054
# Processing bctech2055
# Processing bctech2056
# Processing bctech2057
# Processing bctech2058
# Processing bctech2059
# Processing bctech2060
# Processing bctech2061
# Processing bctech2062
# Processing bctech2063
# Processing bctech2064
# Processing bctech2065
# Processing bctech2066
# Processing bctech2067
# Processing bctech2068
# Processing bctech2069
# Processing bctech2070
# Processing bctech2071
# Processing bctech2072
# Processing bctech2073
# Processing bctech2074
# Processing bctech2075
# Processing bctech2076
# Processing bctech2077
# Processing bctech2078
# Processing bctech2079
# Processing bctech2080
# Processing bctech2081
# Processing bctech2082
# Processing bctech2083
# Processing bctech2084
# Processing bctech2085
# Processing bctech2086
# Processing bctech2087
# Processing bctech2088
# Processing bctech2089
# Processing bctech2090
# Processing bctech2091
# Processing bctech2092
# Processing bctech2093
# Processing bctech2094
# Processing bctech2095
# Processing bctech2096
# Processing bctech2097
# Processing bctech2098
# Processing bctech2099
# Processing bctech2100
# Processing bctech2101
# Processing bctech2102
# Processing bctech2103
# Processing bctech2104
# Processing bctech2105
# Processing bctech2106
# Processing bctech2107
# Processing bctech2108
# Processing bctech2109
# Processing bctech2110
# Processing bctech2111
# Processing bctech2112
# Processing bctech2113
# Processing bctech2114
# Processing bctech2115
# Processing bctech2116
# Processing bctech2117
# Processing bctech2118
# Processing bctech2119
# Processing bctech2120
# Processing bctech2121
# Processing bctech2122
# Processing bctech2123
# Processing bctech2124
# Processing bctech2125
# Processing bctech2126
# Processing bctech2127
# Processing bctech2128
# Processing bctech2129
# Processing bctech2130
# Processing bctech2131
# Processing bctech2132
# Processing bctech2133
# Processing bctech2134
# Processing bctech2135
# Processing bctech2136
# Processing bctech2137
# Processing bctech2138
# Processing bctech2139
# Processing bctech2140
# Processing bctech2141
# Processing bctech2142
# Processing bctech2143
# Processing bctech2144
# Processing bctech2145
# Processing bctech2146
# Processing bctech2147
# Processing bctech2148
# Processing bctech2149
# Processing bctech2150
# Processing bctech2151
# Processing bctech2152
# Processing bctech2153
# Processing bctech2154
# Processing bctech2155
# Processing bctech2156
# Processing bctech2157
# Analysis complete
